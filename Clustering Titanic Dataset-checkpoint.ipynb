# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from sklearn import preprocessing
from sklearn.metrics import accuracy_score
import xgboost as xgb
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# %%
titanic = pd.read_csv('titanic-train.csv')
titanic.set_index('PassengerId', inplace=True)
titanic
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
titanic.isnull().sum() #cek missing value
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
# imputasi data dr kolom age menggunakan mean
mean_age = titanic['Age'].mean()
titanic['Age'].fillna(mean_age, inplace=True)
titanic
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# ...

# %%
# drop kolom Cabin karena missing valuenya lebih dari 50%
titanic.drop(columns=['Cabin'], inplace=True)
titanic
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# ...                                                        ...     ...
# ...

# %%
#drop kolom-kolom yg tidak digunakan
titanic.drop(columns=['Name', 'Embarked', 'Ticket'], inplace=True)
titanic
# Out:
#              Survived  Pclass     Sex        Age  SibSp  Parch     Fare
# PassengerId
# 1                   0       3    male  22.000000      1      0   7.2500
# 2                   1       1  female  38.000000      1      0  71.2833
# 3                   1       3  female  26.000000      0      0   7.9250
# 4                   1       1  female  35.000000      1      0  53.1000
# 5                   0       3    male  35.000000      0      0   8.0500
# ...               ...     ...     ...        ...    ...    ...      ...
# 887                 0       2    male  27.000000      0      0  13.0000
# 888                 1       1  female  19.000000      0      0  30.0000
# 889                 0       3  female  29.699118      1      2  23.4500
# 890                 1       1    male  26.000000      0      0  30.0000
# 891                 0       3    male  32.000000      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
# mengubah tipe data sex menjadi numerik
encoder = OrdinalEncoder()
titanic['Sex'] = encoder.fit_transform(titanic[['Sex']])
titanic
# Out:
#              Survived  Pclass  Sex        Age  SibSp  Parch     Fare
# PassengerId
# 1                   0       3  1.0  22.000000      1      0   7.2500
# 2                   1       1  0.0  38.000000      1      0  71.2833
# 3                   1       3  0.0  26.000000      0      0   7.9250
# 4                   1       1  0.0  35.000000      1      0  53.1000
# 5                   0       3  1.0  35.000000      0      0   8.0500
# ...               ...     ...  ...        ...    ...    ...      ...
# 887                 0       2  1.0  27.000000      0      0  13.0000
# 888                 1       1  0.0  19.000000      0      0  30.0000
# 889                 0       3  0.0  29.699118      1      2  23.4500
# 890                 1       1  1.0  26.000000      0      0  30.0000
# 891                 0       3  1.0  32.000000      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
#cek tipe data
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    float64
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
# dtypes: float64(3), int64(4)
# memory usage: 55.7 KB

# %%
#korelasi heatmap
titanic_corr = titanic.corr()
plt.figure(figsize=(20, 20))
sns.heatmap(titanic_corr, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Korelasi')
plt.show()

# %% [markdown]
# 2) Dari hasil heatmap dapat dilihat bahwasanya variabel fare dengan variabel survived memiliki nilai korelasi = 0.26 (tertinggi dibanding variabel lainnya) Maka variabel fare sangat berpengaruh dengan variabel survived. Yang artinya semakin tinggi nilai variabel fare maka semakin tinggi harapan survived seseorang.

# %%
# menentukan variabel dependen dan independen
X = titanic.drop('Survived', axis=1)
y = titanic['Survived']

# %%
y
# Out:
# PassengerId
# 1      0
# 2      1
# 3      1
# 4      1
# 5      0
#       ..
# 887    0
# 888    1
# 889    0
# 890    1
# 891    0
# Name: Survived, Length: 891, dtype: int64

# %%
X
# Out:
#              Pclass  Sex        Age  SibSp  Parch     Fare
# PassengerId
# 1                 3  1.0  22.000000      1      0   7.2500
# 2                 1  0.0  38.000000      1      0  71.2833
# 3                 3  0.0  26.000000      0      0   7.9250
# 4                 1  0.0  35.000000      1      0  53.1000
# 5                 3  1.0  35.000000      0      0   8.0500
# ...             ...  ...        ...    ...    ...      ...
# 887               2  1.0  27.000000      0      0  13.0000
# 888               1  0.0  19.000000      0      0  30.0000
# 889               3  0.0  29.699118      1      2  23.4500
# 890               1  1.0  26.000000      0      0  30.0000
# 891               3  1.0  32.000000      0      0   7.7500
#
# [891 rows x 6 columns]

# %%
y.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
import scipy.stats as stats

# Data dari tabel kontingensi
observed_data = [[549, None],
                 [None, 342]]

# Mengisi nilai yang hilang sesuai dengan hasil perbandingan yang ada
total = 549 + 342
observed_data[0][1] = total - 549
observed_data[1][0] = total - 342

# Menghitung chi-squared dan p-value
chi2, p, _, _ = stats.chi2_contingency(observed_data)

# Derajat kebebasan
df = (len(observed_data) - 1) * (len(observed_data[0]) - 1)

# Tingkat signifikansi
alpha = 0.05

# Menampilkan hasil
print("Chi-squared:", chi2)
print("Derajat Kebebasan (df):", df)
print("p-value:", p)

# Uji signifikansi
if p < alpha:
    print("Tolak hipotesis nol: Terdapat hubungan yang signifikan antara Independents dan Dependents.")
else:
    print("Tidak cukup bukti untuk menolak hipotesis nol: Perbandingan seimbang atau acak.")
# Out:
# Chi-squared: 0.0
# Derajat Kebebasan (df): 1
# p-value: 1.0
# Tidak cukup bukti untuk menolak hipotesis nol: Perbandingan seimbang atau acak.

# %% [markdown]
# 1) Evaluasi model tidak harus menggunakan F1 score, tergantung dari konteks tujuan bisnis. Jika tujuannya untuk menghindari false positif, maka presisi dan F1 score wajib digunakan. Tetapi jika distribusi kelas seimbang, maka akurasi saja cukup. Untuk mengetahui apakah distribusinya seimbang bisa melalui chi square. Karena hasil dari chi square seimbang, maka cukup menggunakan akurasi saja.

# %%
#menyamaratakan menggunakan min max scalling
transformasi_min_max=preprocessing.MinMaxScaler()

nama_var_x = []
for kol in X.columns:
  nama_var_x.append(kol)

X = pd.DataFrame(data=transformasi_min_max.fit_transform(X), columns=nama_var_x)
X
# Out:
#      Pclass  Sex       Age  SibSp     Parch      Fare
# 0       1.0  1.0  0.271174  0.125  0.000000  0.014151
# 1       0.0  0.0  0.472229  0.125  0.000000  0.139136
# 2       1.0  0.0  0.321438  0.000  0.000000  0.015469
# 3       0.0  0.0  0.434531  0.125  0.000000  0.103644
# 4       1.0  1.0  0.434531  0.000  0.000000  0.015713
# ..      ...  ...       ...    ...       ...       ...
# 886     0.5  1.0  0.334004  0.000  0.000000  0.025374
# 887     0.0  0.0  0.233476  0.000  0.000000  0.058556
# 888     1.0  0.0  0.367921  0.125  0.333333  0.045771
# 889     0.0  1.0  0.321438  0.000  0.000000  0.058556
# 890     1.0  1.0  0.396833  0.000  0.000000  0.015127
#
# [891 rows x 6 columns]

# %%
#spliting data menjadi data test dan data train 75:25
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=100)

# %%
X_test
# Out:
#      Pclass  Sex       Age  SibSp     Parch      Fare
# 205     1.0  0.0  0.019854    0.0  0.166667  0.020421
# 44      1.0  0.0  0.233476    0.0  0.000000  0.015379
# 821     1.0  1.0  0.334004    0.0  0.000000  0.016908
# 458     0.5  0.0  0.623021    0.0  0.000000  0.020495
# 795     0.5  1.0  0.484795    0.0  0.000000  0.025374
# ..      ...  ...       ...    ...       ...       ...
# 153     1.0  1.0  0.503644    0.0  0.333333  0.028302
# 288     0.5  1.0  0.522493    0.0  0.000000  0.025374
# 244     1.0  1.0  0.371701    0.0  0.000000  0.014102
# 680     1.0  0.0  0.367921    0.0  0.000000  0.015883
# 796     0.0  0.0  0.610455    0.0  0.000000  0.050610
#
# [223 rows x 6 columns]

# %%
y_test
# Out:
# PassengerId
# 206    0
# 45     1
# 822    1
# 459    1
# 796    0
#       ..
# 154    0
# 289    1
# 245    0
# 681    0
# 797    1
# Name: Survived, Length: 223, dtype: int64

# %%
# K-Nearest Neighbors (KNN)
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
knn_pred = knn.predict(X_test)

# Decision Tree
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
dt_pred = dt.predict(X_test)

# Random Forest
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
rf_pred = rf.predict(X_test)

# XGBoost
xgb_model = xgb.XGBClassifier()
xgb_model.fit(X_train, y_train)
xgb_pred = xgb_model.predict(X_test)

# %%
actual = y_test  # Actual target values
# Create confusion matrices
knn_cm = confusion_matrix(actual, knn_pred)
dt_cm = confusion_matrix(actual, dt_pred)
rf_cm = confusion_matrix(actual, rf_pred)
xgb_cm = confusion_matrix(actual, xgb_pred)

# Convert confusion matrices to DataFrames
def confusion_matrix_to_dataframe(cm):
    labels = sorted(set(actual))
    df_cm = pd.DataFrame(cm, index=labels, columns=labels)
    df_cm.index.name = 'Actual'
    df_cm.columns.name = 'Predicted'
    return df_cm

# Convert confusion matrices to DataFrames with labels
knn_cm_df = confusion_matrix_to_dataframe(knn_cm)
dt_cm_df = confusion_matrix_to_dataframe(dt_cm)
rf_cm_df = confusion_matrix_to_dataframe(rf_cm)
xgb_cm_df = confusion_matrix_to_dataframe(xgb_cm)

# %%
#confusion matrix KNN
knn_cm_df
# Out:
# Predicted    0   1
# Actual
# 0          114  13
# 1           33  63

# %%
#confusion matrix decission tree
dt_cm_df
# Out:
# Predicted    0   1
# Actual
# 0          100  27
# 1           30  66

# %%
#confusion matrix random forest
rf_cm_df
# Out:
# Predicted    0   1
# Actual
# 0          110  17
# 1           27  69

# %%
#confusion matrix xgboost
xgb_cm_df
# Out:
# Predicted    0   1
# Actual
# 0          107  20
# 1           31  65

# %%
# Menghitung akurasi untuk model K-Nearest Neighbors (KNN)
knn_accuracy = accuracy_score(y_test, knn_pred)

# Menghitung akurasi untuk model Decision Tree
dt_accuracy = accuracy_score(y_test, dt_pred)

# Menghitung akurasi untuk model Random Forest
rf_accuracy = accuracy_score(y_test, rf_pred)

# Menghitung akurasi untuk model XGBoost
xgb_accuracy = accuracy_score(y_test, xgb_pred)

# Menampilkan hasil akurasi untuk setiap model
print("K-Nearest Neighbors (KNN) Accuracy:", knn_accuracy)
print("Decision Tree Accuracy:", dt_accuracy)
print("Random Forest Accuracy:", rf_accuracy)
print("XGBoost Accuracy:", xgb_accuracy)
# Out:
# K-Nearest Neighbors (KNN) Accuracy: 0.7937219730941704
# Decision Tree Accuracy: 0.7443946188340808
# Random Forest Accuracy: 0.8026905829596412
# XGBoost Accuracy: 0.7713004484304933

# %%
models = {
    'K-Nearest Neighbors (KNN)': knn_accuracy,
    'Decision Tree': dt_accuracy,
    'Random Forest': rf_accuracy,
    'XGBoost': xgb_accuracy
}

best_model_name = max(models, key=models.get)
print("Best Model:", best_model_name)
# Out:
# Best Model: Random Forest

# %% [markdown]
# __Prediksi dengan data test baru__

# %%
# Load data test
titanic_test = pd.read_csv('titanic-test.csv')
titanic_test.set_index('PassengerId', inplace=True)
titanic_test
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...             ...                                           ...     ...
# 1305              3                            Spector, Mr. Woolf    male
# 1306              1                  Oliva y Ocana, Dona. Fermina  female
# 1307              3                  Saether, Mr. Simon Sivertsen    male
# 1308              3                           Ware, Mr. Frederick    male
# 1309              3                      Peter, Master. Michael J    male
#
# ...

# %%
titanic_test.isnull().sum() #cek missing value
# Out:
# Pclass        0
# Name          0
# Sex           0
# Age          86
# SibSp         0
# Parch         0
# Ticket        0
# Fare          1
# Cabin       327
# Embarked      0
# dtype: int64

# %%
# imputasi data dr kolom age menggunakan mean
mean_age = titanic_test['Age'].mean()
titanic_test['Age'].fillna(mean_age, inplace=True)
titanic_test
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...             ...                                           ...     ...
# 1305              3                            Spector, Mr. Woolf    male
# 1306              1                  Oliva y Ocana, Dona. Fermina  female
# 1307              3                  Saether, Mr. Simon Sivertsen    male
# 1308              3                           Ware, Mr. Frederick    male
# 1309              3                      Peter, Master. Michael J    male
#
# ...

# %%
# drop kolom Cabin karena missing valuenya lebih dari 50%
titanic_test.drop(columns=['Cabin'], inplace=True)
titanic_test
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...             ...                                           ...     ...
# 1305              3                            Spector, Mr. Woolf    male
# 1306              1                  Oliva y Ocana, Dona. Fermina  female
# 1307              3                  Saether, Mr. Simon Sivertsen    male
# 1308              3                           Ware, Mr. Frederick    male
# 1309              3                      Peter, Master. Michael J    male
#
# ...

# %%
#drop kolom-kolom yg tidak digunakan
titanic_test.drop(columns=['Name', 'Embarked', 'Ticket'], inplace=True)
titanic_test
# Out:
#              Pclass     Sex       Age  SibSp  Parch      Fare
# PassengerId
# 892               3    male  34.50000      0      0    7.8292
# 893               3  female  47.00000      1      0    7.0000
# 894               2    male  62.00000      0      0    9.6875
# 895               3    male  27.00000      0      0    8.6625
# 896               3  female  22.00000      1      1   12.2875
# ...             ...     ...       ...    ...    ...       ...
# 1305              3    male  30.27259      0      0    8.0500
# 1306              1  female  39.00000      0      0  108.9000
# 1307              3    male  38.50000      0      0    7.2500
# 1308              3    male  30.27259      0      0    8.0500
# 1309              3    male  30.27259      1      1   22.3583
#
# [418 rows x 6 columns]

# %%
# mengubah tipe data sex menjadi numerik
encoder = OrdinalEncoder()
titanic_test['Sex'] = encoder.fit_transform(titanic_test[['Sex']])
titanic_test
# Out:
#              Pclass  Sex       Age  SibSp  Parch      Fare
# PassengerId
# 892               3  1.0  34.50000      0      0    7.8292
# 893               3  0.0  47.00000      1      0    7.0000
# 894               2  1.0  62.00000      0      0    9.6875
# 895               3  1.0  27.00000      0      0    8.6625
# 896               3  0.0  22.00000      1      1   12.2875
# ...             ...  ...       ...    ...    ...       ...
# 1305              3  1.0  30.27259      0      0    8.0500
# 1306              1  0.0  39.00000      0      0  108.9000
# 1307              3  1.0  38.50000      0      0    7.2500
# 1308              3  1.0  30.27259      0      0    8.0500
# 1309              3  1.0  30.27259      1      1   22.3583
#
# [418 rows x 6 columns]

# %%
# imputasi data dr kolom fare menggunakan mean
mean_fare = titanic_test['Fare'].mean()
titanic_test['Fare'].fillna(mean_fare, inplace=True)
titanic_test
# Out:
#              Pclass  Sex       Age  SibSp  Parch      Fare
# PassengerId
# 892               3  1.0  34.50000      0      0    7.8292
# 893               3  0.0  47.00000      1      0    7.0000
# 894               2  1.0  62.00000      0      0    9.6875
# 895               3  1.0  27.00000      0      0    8.6625
# 896               3  0.0  22.00000      1      1   12.2875
# ...             ...  ...       ...    ...    ...       ...
# 1305              3  1.0  30.27259      0      0    8.0500
# 1306              1  0.0  39.00000      0      0  108.9000
# 1307              3  1.0  38.50000      0      0    7.2500
# 1308              3  1.0  30.27259      0      0    8.0500
# 1309              3  1.0  30.27259      1      1   22.3583
#
# [418 rows x 6 columns]

# %%
#cek tipe data
titanic_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 418 entries, 892 to 1309
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Pclass  418 non-null    int64
#  1   Sex     418 non-null    float64
#  2   Age     418 non-null    float64
#  3   SibSp   418 non-null    int64
#  4   Parch   418 non-null    int64
#  5   Fare    418 non-null    float64
# dtypes: float64(3), int64(3)
# memory usage: 22.9 KB

# %%
#korelasi heatmap
titanic_corr = titanic_test.corr()
plt.figure(figsize=(20, 20))
sns.heatmap(titanic_corr, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Korelasi')
plt.show()

# %%
# Assuming your new data has the same features as your original data (except the target)

# Make predictions using the trained models
knn_predictions = knn.predict(titanic_test)
dt_predictions = dt.predict(titanic_test)
rf_predictions = rf.predict(titanic_test)
xgb_predictions = xgb_model.predict(titanic_test)


combined_data = titanic_test.copy()  # Copy the new dataset

# Add columns for predicted labels
combined_data['KNN_Predictions'] = knn_predictions
combined_data['DT_Predictions'] = dt_predictions
combined_data['RF_Predictions'] = rf_predictions
combined_data['XGB_Predictions'] = xgb_predictions

# %%
combined_data
# Out:
#              Pclass  Sex       Age  SibSp  Parch      Fare  KNN_Predictions  \
# PassengerId
# 892               3  1.0  34.50000      0      0    7.8292                0
# 893               3  0.0  47.00000      1      0    7.0000                0
# 894               2  1.0  62.00000      0      0    9.6875                0
# 895               3  1.0  27.00000      0      0    8.6625                0
# 896               3  0.0  22.00000      1      1   12.2875                1
# ...             ...  ...       ...    ...    ...       ...              ...
# 1305              3  1.0  30.27259      0      0    8.0500                0
# 1306              1  0.0  39.00000      0      0  108.9000                1
# 1307              3  1.0  38.50000      0      0    7.2500                0
# 1308              3  1.0  30.27259      0      0    8.0500                0
# 1309              3  1.0  30.27259      1      1   22.3583                1
#
# ...

# %% [markdown]
# 3) maksud dari kolom KNN_prediction, DT_Prediction, RF_Prediction, XGB_prediction adalah hasil prediksi dari masing-masing model. Seperti contoh penumpang dengan passengerId 892 ketika diprediksi menggunakan metode knn, decission tree, dan xgboost maka hasilnya meninggal dunia, tetapi hasil prediksi menggunakan random forest hasilnya hidup. Mengapa bisa random forest memiliki hasil yang cenderung berbeda dari ketiga model lainnya? karena dapat dilihat pada hasil akurasi, ketiga model memiliki hasil akurasi 80% sedangkan ketiga model lainnya di angka 70-an%, oleh karena itu prediksi dari random forest dinilai lebih akurat daripada ketiga model lainnya.
